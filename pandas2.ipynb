# %%
person = {
    "first": "heet",
    "last": "bhatt",
    "emamil": "bhattheet177@gamil.com"
}

# %%
people = {
    "first": ["heet"],
    "last": ["bhatt"],
    "email": ["bhattheet177@gamil.com"]
}

# %%
people = {
    "first": ["heet" , 'Neel' , 'Ajay'],
    "last": ["bhatt" , 'Arora' , 'Pandey'],
    "email": ["bhattheet177@gamil.com" , 'Aroraneel@gmail.com' , 'Ajaypandey@gmail.com']
}

# %%
people['email']
# Out:
# ['bhattheet177@gamil.com', 'Aroraneel@gmail.com', 'Ajaypandey@gmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   first    last                   email
# 0  heet   bhatt  bhattheet177@gamil.com
# 1  Neel   Arora     Aroraneel@gmail.com
# 2  Ajay  Pandey    Ajaypandey@gmail.com

# %%
df['email']
# Out:
# 0    bhattheet177@gamil.com
# 1       Aroraneel@gmail.com
# 2      Ajaypandey@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0    bhattheet177@gamil.com
# 1       Aroraneel@gmail.com
# 2      Ajaypandey@gmail.com
# Name: email, dtype: object

# %%
df[['email', 'last']]
# Out:
#                     email    last
# 0  bhattheet177@gamil.com   bhatt
# 1     Aroraneel@gmail.com   Arora
# 2    Ajaypandey@gmail.com  Pandey

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                      heet
# last                      bhatt
# email    bhattheet177@gamil.com
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# first                   Neel
# last                   Arora
# email    Aroraneel@gmail.com
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# first                    Ajay
# last                   Pandey
# email    Ajaypandey@gmail.com
# Name: 2, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#   first    last                   email
# 0  heet   bhatt  bhattheet177@gamil.com
# 1  Neel   Arora     Aroraneel@gmail.com
# 2  Ajay  Pandey    Ajaypandey@gmail.com

# %%
df.iloc[[0,1], 0]
# Out:
# 0    heet
# 1    Neel
# Name: first, dtype: object

# %%
df.loc[0]
# Out:
# first                      heet
# last                      bhatt
# email    bhattheet177@gamil.com
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#   first   last                   email
# 0  heet  bhatt  bhattheet177@gamil.com
# 1  Neel  Arora     Aroraneel@gmail.com

# %%
df.loc[[0,1,2] , 'first']
# Out:
# 0    heet
# 1    Neel
# 2    Ajay
# Name: first, dtype: object

# %%
df.loc[[0,1,2] , ['first' , 'email', 'last']]
# Out:
#   first                   email    last
# 0  heet  bhattheet177@gamil.com   bhatt
# 1  Neel     Aroraneel@gmail.com   Arora
# 2  Ajay    Ajaypandey@gmail.com  Pandey
